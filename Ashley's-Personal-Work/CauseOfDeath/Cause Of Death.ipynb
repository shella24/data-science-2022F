# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas_profiling import ProfileReport
cod = pd.read_csv('cause_of_deaths.csv')

# %%
cod
# Out:
#      Country/Territory Code  Year  Meningitis  \
# 0          Afghanistan  AFG  1990        2159
# 1          Afghanistan  AFG  1991        2218
# 2          Afghanistan  AFG  1992        2475
# 3          Afghanistan  AFG  1993        2812
# 4          Afghanistan  AFG  1994        3027
# ...                ...  ...   ...         ...
# 6115          Zimbabwe  ZWE  2015        1439
# 6116          Zimbabwe  ZWE  2016        1457
# 6117          Zimbabwe  ZWE  2017        1460
# 6118          Zimbabwe  ZWE  2018        1450
# 6119          Zimbabwe  ZWE  2019        1450
#
#       Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                        1116                  371
# 1                                        1136                  374
# 2                                        1162                  378
# 3                                        1187                  384
# 4                                        1211                  391
# ...

# %% [markdown]
# # Cleaning the Data

# %%
for col in cod.columns:
    pct_missing = np.mean(cod[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Country/Territory - 0%
# Code - 0%
# Year - 0%
# Meningitis - 0%
# Alzheimer's Disease and Other Dementias - 0%
# Parkinson's Disease - 0%
# Nutritional Deficiencies - 0%
# Malaria - 0%
# Drowning - 0%
# Interpersonal Violence - 0%
# Maternal Disorders - 0%
# HIV/AIDS - 0%
# Drug Use Disorders - 0%
# Tuberculosis - 0%
# Cardiovascular Diseases - 0%
# Lower Respiratory Infections - 0%
# Neonatal Disorders - 0%
# Alcohol Use Disorders - 0%
# Self-harm - 0%
# Exposure to Forces of Nature - 0%
# Diarrheal Diseases - 0%
# Environmental Heat and Cold Exposure - 0%
# Neoplasms - 0%
# Conflict and Terrorism - 0%
# Diabetes Mellitus - 0%
# Chronic Kidney Disease - 0%
# Poisonings - 0%
# Protein-Energy Malnutrition - 0%
# Road Injuries - 0%
# Chronic Respiratory Diseases - 0%
# Cirrhosis and Other Chronic Liver Diseases - 0%
# Digestive Diseases - 0%
# Fire, Heat, and Hot Substances - 0%
# Acute Hepatitis - 0%

# %%
cod.rename(columns = {"Alzheimer's Disease and Other Dementias":"Alzheimer's Disease", 'Cirrhosis and Other Chronic Liver Diseases':'Chronic Liver Diseases','Fire, Heat, and Hot Substances':'Hot Substances', 'Country/Territory':'Country'}, inplace = True)

# %%
#ProfileReport(cod)

# %% [markdown]
# # Code  - Visuals

# %%
cod
# Out:
#           Country Code  Year  Meningitis  Alzheimer's Disease  \
# 0     Afghanistan  AFG  1990        2159                 1116
# 1     Afghanistan  AFG  1991        2218                 1136
# 2     Afghanistan  AFG  1992        2475                 1162
# 3     Afghanistan  AFG  1993        2812                 1187
# 4     Afghanistan  AFG  1994        3027                 1211
# ...           ...  ...   ...         ...                  ...
# 6115     Zimbabwe  ZWE  2015        1439                  754
# 6116     Zimbabwe  ZWE  2016        1457                  767
# 6117     Zimbabwe  ZWE  2017        1460                  781
# 6118     Zimbabwe  ZWE  2018        1450                  795
# 6119     Zimbabwe  ZWE  2019        1450                  812
#
#       Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                     371                      2087       93      1370
# 1                     374                      2153      189      1391
# ...

# %% [markdown]
# ### Line chart that shows in increase of the first 5 diseases in Afghanistan

# %%
AFGCrime = cod.loc[cod.Country == 'Afghanistan'].head(6)
AFGCrime
# Out:
#        Country Code  Year  Meningitis  Alzheimer's Disease  \
# 0  Afghanistan  AFG  1990        2159                 1116
# 1  Afghanistan  AFG  1991        2218                 1136
# 2  Afghanistan  AFG  1992        2475                 1162
# 3  Afghanistan  AFG  1993        2812                 1187
# 4  Afghanistan  AFG  1994        3027                 1211
# 5  Afghanistan  AFG  1995        3102                 1225
#
#    Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                  371                      2087       93      1370
# 1                  374                      2153      189      1391
# 2                  378                      2441      239      1514
# 3                  384                      2837      108      1687
# 4                  391                      3081      211      1809
# 5                  394                      3131      175      1881
#
# ...

# %%
sns.lineplot(data=AFGCrime, x="Year", y="Meningitis").set(xlabel ="Year", ylabel = "5 Diseases", title ='First 5 Disieases')
sns.lineplot(data=AFGCrime, x="Year", y="Alzheimer's Disease")
sns.lineplot(data=AFGCrime, x="Year", y="Parkinson's Disease")
sns.lineplot(data=AFGCrime, x="Year", y="Nutritional Deficiencies")
sns.lineplot(data=AFGCrime, x="Year", y="Malaria")
# Out:
# <AxesSubplot:title={'center':'First 5 Disieases'}, xlabel='Year', ylabel='5 Diseases'>

# %% [markdown]
# ###  For Visme

# %%
cod
# Out:
#           Country Code  Year  Meningitis  Alzheimer's Disease  \
# 0     Afghanistan  AFG  1990        2159                 1116
# 1     Afghanistan  AFG  1991        2218                 1136
# 2     Afghanistan  AFG  1992        2475                 1162
# 3     Afghanistan  AFG  1993        2812                 1187
# 4     Afghanistan  AFG  1994        3027                 1211
# ...           ...  ...   ...         ...                  ...
# 6115     Zimbabwe  ZWE  2015        1439                  754
# 6116     Zimbabwe  ZWE  2016        1457                  767
# 6117     Zimbabwe  ZWE  2017        1460                  781
# 6118     Zimbabwe  ZWE  2018        1450                  795
# 6119     Zimbabwe  ZWE  2019        1450                  812
#
#       Parkinson's Disease  Nutritional Deficiencies  Malaria  Drowning  \
# 0                     371                      2087       93      1370
# 1                     374                      2153      189      1391
# ...

# %%
Zimbabwe_data = cod.loc[cod.Country == 'Zimbabwe']
Zimbabwe_data
# Out:
#        Country Code  Year  Meningitis  Alzheimer's Disease  \
# 6090  Zimbabwe  ZWE  1990        1132                  457
# 6091  Zimbabwe  ZWE  1991        1179                  476
# 6092  Zimbabwe  ZWE  1992        1099                  494
# 6093  Zimbabwe  ZWE  1993        1038                  509
# 6094  Zimbabwe  ZWE  1994        1060                  527
# 6095  Zimbabwe  ZWE  1995        1029                  546
# 6096  Zimbabwe  ZWE  1996         966                  564
# 6097  Zimbabwe  ZWE  1997         977                  584
# 6098  Zimbabwe  ZWE  1998        1041                  609
# 6099  Zimbabwe  ZWE  1999        1139                  635
# 6100  Zimbabwe  ZWE  2000        1243                  661
# 6101  Zimbabwe  ZWE  2001        1301                  679
# 6102  Zimbabwe  ZWE  2002        1381                  695
# 6103  Zimbabwe  ZWE  2003        1442                  703
# 6104  Zimbabwe  ZWE  2004        1503                  710
# ...

# %%
ZimNew = Zimbabwe_data.drop(['Country','Code', 'Year'], axis=1)
ZimNew
# Out:
#       Meningitis  Alzheimer's Disease  Parkinson's Disease  \
# 6090        1132                  457                  123
# 6091        1179                  476                  129
# 6092        1099                  494                  136
# 6093        1038                  509                  142
# 6094        1060                  527                  148
# 6095        1029                  546                  156
# 6096         966                  564                  161
# 6097         977                  584                  167
# 6098        1041                  609                  176
# 6099        1139                  635                  184
# 6100        1243                  661                  193
# 6101        1301                  679                  198
# 6102        1381                  695                  203
# 6103        1442                  703                  206
# 6104        1503                  710                  209
# ...

# %%
#https://sparkbyexamples.com/pandas/pandas-iterate-over-columns-of-dataframe-to-run-regression/
for column in ZimNew:
    print(ZimNew[column].sum())
# Out:
# 41238
# 20017
# 5764
# 66723
# 118728
# 18169
# 32741
# 29802
# 1836042
# 2271
# 273844
# 408352
# 326145
# 251875
# 1246
# 51763
# 1247
# 140850
# 978
# 272787
# 625
# 71175
# 49952
# 9113
# 65942
# 67207
# 71774
# 55027
# 108691
# 14718
# 3778

# %%
ZValue = [41238, 20017, 5764, 66723, 118728, 18169, 32741, 29802, 1836042, 2271, 273844, 408352, 326145, 251875, 1246, 51763, 1247, 140850, 978, 272787, 625, 71175, 49952, 9113, 65942, 67207, 71774, 55027, 108691, 14718, 3778]
ZValue
# Out:
# [41238,
#  20017,
#  5764,
#  66723,
#  118728,
#  18169,
#  32741,
#  29802,
#  1836042,
#  2271,
#  273844,
#  408352,
#  326145,
#  251875,
#  1246,
#  51763,
#  1247,
#  140850,
#  978,
#  272787,
#  625,
#  71175,
#  49952,
#  9113,
#  65942,
#  67207,
#  71774,
#  55027,
#  108691,
#  14718,
#  3778]

# %%
ZKey = ZimNew.columns
ZKey
# Out:
# Index(['Meningitis', 'Alzheimer's Disease', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Chronic Liver Diseases', 'Digestive Diseases', 'Hot Substances',
#        'Acute Hepatitis'],
#       dtype='object')

# %%
ZimbabweDict = dict(zip(ZKey, ZValue))
ZimbabweDict
#https://careerkarma.com/blog/python-convert-list-to-dictionary/
# Out:
# {'Meningitis': 41238,
#  "Alzheimer's Disease": 20017,
#  "Parkinson's Disease": 5764,
#  'Nutritional Deficiencies': 66723,
#  'Malaria': 118728,
#  'Drowning': 18169,
#  'Interpersonal Violence': 32741,
#  'Maternal Disorders': 29802,
#  'HIV/AIDS': 1836042,
#  'Drug Use Disorders': 2271,
#  'Tuberculosis': 273844,
#  'Cardiovascular Diseases': 408352,
#  'Lower Respiratory Infections': 326145,
#  'Neonatal Disorders': 251875,
#  'Alcohol Use Disorders': 1246,
#  'Self-harm': 51763,
#  'Exposure to Forces of Nature': 1247,
#  'Diarrheal Diseases': 140850,
#  'Environmental Heat and Cold Exposure': 978,
#  'Neoplasms': 272787,
#  'Conflict and Terrorism': 625,
#  'Diabetes Mellitus': 71175,
#  'Chronic Kidney Disease': 49952,
#  'Poisonings': 9113,
#  'Protein-Energy Malnutrition': 65942,
#  'Road Injuries': 67207,
#  'Chronic Respiratory Diseases': 71774,
#  'Chronic Liver Diseases': 55027,
#  'Digestive Diseases': 108691,
#  'Hot Substances': 14718,
#  'Acute Hepatitis': 3778}

# %%
#https://stackoverflow.com/questions/25318639/create-python-dataframe-from-dictionary-where-keys-are-the-column-names-and-valu

Zdf = pd.DataFrame(ZimbabweDict, index=['Zimbabwe',])
Zdf
# Out:
#           Meningitis  Alzheimer's Disease  Parkinson's Disease  \
# Zimbabwe       41238                20017                 5764
#
#           Nutritional Deficiencies  Malaria  Drowning  Interpersonal Violence  \
# Zimbabwe                     66723   118728     18169                   32741
#
#           Maternal Disorders  HIV/AIDS  Drug Use Disorders  ...  \
# Zimbabwe               29802   1836042                2271  ...
#
#           Diabetes Mellitus  Chronic Kidney Disease  Poisonings  \
# Zimbabwe              71175                   49952        9113
#
#           Protein-Energy Malnutrition  Road Injuries  \
# Zimbabwe                        65942          67207
#
#           Chronic Respiratory Diseases  Chronic Liver Diseases  \
# Zimbabwe                         71774                   55027
#
#           Digestive Diseases  Hot Substances  Acute Hepatitis
# Zimbabwe              108691           14718             3778
#
# [1 rows x 31 columns]

# %%
TopZdf = Zdf.loc[:, ["HIV/AIDS","Malaria","Digestive Diseases"]]
# Out:
# Meningitis                              1
# Alzheimer's Disease                     1
# Parkinson's Disease                     1
# Nutritional Deficiencies                1
# Malaria                                 1
# Drowning                                1
# Interpersonal Violence                  1
# Maternal Disorders                      1
# HIV/AIDS                                1
# Drug Use Disorders                      1
# Tuberculosis                            1
# Cardiovascular Diseases                 1
# Lower Respiratory Infections            1
# Neonatal Disorders                      1
# Alcohol Use Disorders                   1
# Self-harm                               1
# Exposure to Forces of Nature            1
# Diarrheal Diseases                      1
# Environmental Heat and Cold Exposure    1
# Neoplasms                               1
# Conflict and Terrorism                  1
# Diabetes Mellitus                       1
# ...
