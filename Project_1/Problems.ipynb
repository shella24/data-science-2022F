# %% [markdown]
# # Python Project

# %%
import pandas as pd

# %%
from pandas_profiling import ProfileReport

# %%
college = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv')
college
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %% [markdown]
# Question #1

# %% [markdown]
# how many majors in each category

# %%
count = college.groupby('Major_category').Major_category.count()
count.sort_values()
# Out:
# Major_category
# Interdisciplinary                       1
# Communications & Journalism             4
# Law & Public Policy                     5
# Industrial Arts & Consumer Services     7
# Arts                                    8
# Psychology & Social Work                9
# Social Science                          9
# Agriculture & Natural Resources        10
# Physical Sciences                      10
# Computers & Mathematics                11
# Health                                 12
# Business                               13
# Biology & Life Science                 14
# Humanities & Liberal Arts              15
# Education                              16
# Engineering                            29
# Name: Major_category, dtype: int64

# %% [markdown]
# Question #2

# %% [markdown]
# all majors in health category all majors where women outnumber the men

# %%
health = college.loc[college.Major_category == 'Health']
health
# Out:
#      Rank  Major_code                                              Major  \
# 34     35        6107                                            NURSING
# 44     45        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 51     52        6104                         MEDICAL ASSISTING SERVICES
# 60     61        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 88     89        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# 103   104        4002                                 NUTRITION SCIENCES
# 104   105        6103         HEALTH AND MEDICAL ADMINISTRATIVE SERVICES
# 118   119        6110                        COMMUNITY AND PUBLIC HEALTH
# 121   122        6106            HEALTH AND MEDICAL PREPARATORY PROGRAMS
# 126   127        6109                      TREATMENT THERAPY PROFESSIONS
# 134   135        6100                GENERAL MEDICAL AND HEALTH SERVICES
# 163   164        6102      COMMUNICATION DISORDERS SCIENCES AND SERVICES
#
# ...

# %% [markdown]
# A person wants to go into Biology and Life Science. print the name of which major would be better to go into based on which has the highest amount of employed full time year round people.

# %%
bio = college.loc[college.Major_category == 'Biology & Life Science']
bio
# Out:
#      Rank  Major_code                                Major     Total  \
# 48     49        3607                         PHARMACOLOGY    1762.0
# 54     55        4006  COGNITIVE SCIENCE AND BIOPSYCHOLOGY    3831.0
# 61     62        3603                    MOLECULAR BIOLOGY   18300.0
# 67     68        3605                             GENETICS    3635.0
# 80     81        3606                         MICROBIOLOGY   15232.0
# 82     83        3601                 BIOCHEMICAL SCIENCES   39107.0
# 83     84        3602                               BOTANY    1329.0
# 92     93        1301                ENVIRONMENTAL SCIENCE   25965.0
# 101   102        3608                           PHYSIOLOGY   22060.0
# 108   109        3611                         NEUROSCIENCE   13663.0
# 122   123        3699                MISCELLANEOUS BIOLOGY   10706.0
# 123   124        3600                              BIOLOGY  280709.0
# 132   133        3604                              ECOLOGY    9154.0
# ...

# %% [markdown]
# Find all the majors where women dominate men

# %%
womenrock = college.loc[college.ShareWomen >= 0.5]

#now = womenrock.Major.to_frame()
#now
# Out:
#                                                  Major
# 7                           ASTRONOMY AND ASTROPHYSICS
# 29                                       PUBLIC POLICY
# 34                                             NURSING
# 39   NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 40                                          ACCOUNTING
# ..                                                 ...
# 168                                            ZOOLOGY
# 169                             EDUCATIONAL PSYCHOLOGY
# 170                                CLINICAL PSYCHOLOGY
# 171                              COUNSELING PSYCHOLOGY
# 172                                    LIBRARY SCIENCE
#
# [96 rows x 1 columns]

# %% [markdown]
# difference between the first and last ranked majors unemployed people

# %%
first = college.iloc[0,12]

last = college.iloc[-1, 12]
print(first,last)
# print(first,last)
difference = first - last
difference
# Out:
# 1207 410
# 797

# %% [markdown]
# Question #4

# %% [markdown]
#  how many people got a full time college job thats no low wage

# %%
total = college.iloc[:,3].sum()
#print(total)
 
low_wage = college.iloc[:,-1].sum()
#print(low_wage)

collegejob = college.iloc[:,-3].sum()
#print(collegejob)

fulltime = college.iloc[:,-9].sum()
#print(fulltime)

best = low_wage + collegejob + fulltime

bestbest = total - best

bestbest
# Out:
# 565092.0

# %% [markdown]
# Question #5

# %% [markdown]
# How many people got a fulltime college job thats not minimum wage

# %%
good_people = college.groupby(['Major','Total','Full_time_year_round','College_jobs','Low_wage_jobs' ])
good_people
# Out:
#   Input In [15]
#     math = total - low_wage = college.iloc[:,-1].sum() + collegejob = college.iloc[:,-3].sum() + fulltime = college.iloc[:,-9].sum()
#            ^
# SyntaxError: cannot assign to operator

# %%
total = college.iloc[:,3].sum()
low_wage = college.iloc[:,-1].sum()
collegejob = college.iloc[:,-3].sum()
fulltime = college.iloc[:,-9].sum()

math = total - low_wage = college.iloc[:,-1].sum() + collegejob = college.iloc[:,-3].sum() + fulltime = college.iloc[:,-9].sum()


people = college.loc[:,['Major','Total','Full_time_year_round','College_jobs','Low_wage_jobs']]
people
# Out:
#                                          Major    Total  Full_time_year_round  \
# 0                        PETROLEUM ENGINEERING   2339.0                  1207
# 1               MINING AND MINERAL ENGINEERING    756.0                   388
# 2                    METALLURGICAL ENGINEERING    856.0                   340
# 3    NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0                   692
# 4                         CHEMICAL ENGINEERING  32260.0                 16697
# ..                                         ...      ...                   ...
# 168                                    ZOOLOGY   8409.0                  3602
# 169                     EDUCATIONAL PSYCHOLOGY   2854.0                  1211
# 170                        CLINICAL PSYCHOLOGY   2838.0                  1293
# 171                      COUNSELING PSYCHOLOGY   4626.0                  2738
# 172                            LIBRARY SCIENCE   1098.0                   410
#
#      College_jobs  Low_wage_jobs
# ...

# %%
menshare = college.iloc[:,3].sum() / college.iloc[:,4].sum()
# Out:
# 2.3541902346870733

# %%
for index in range(len(college)):
    print(college.loc[index, 'Men'] / (college.iloc[:,3]))
# Out:
# 0      0.879436
# 1      2.720899
# 2      2.403037
# 3      1.635135
# 4      0.063763
#          ...
# 168    0.244619
# 169    0.720743
# 170    0.724806
# 171    0.444661
# 172    1.873406
# Name: Total, Length: 173, dtype: float64
# 0      0.290295
# 1      0.898148
# 2      0.793224
# 3      0.539746
# 4      0.021048
#          ...
# 168    0.080747
# 169    0.237912
# 170    0.239253
# 171    0.146779
# 172    0.618397
# Name: Total, Length: 173, dtype: float64
# 0      0.309962
# 1      0.958995
# 2      0.846963
# 3      0.576312
# 4      0.022474
#          ...
# 168    0.086217
# 169    0.254029
# 170    0.255462
# 171    0.156723
# 172    0.660291
# Name: Total, Length: 173, dtype: float64
# 0      0.480120
# 1      1.485450
# 2      1.311916
# 3      0.892687
# 4      0.034811
#          ...
# 168    0.133547
# 169    0.393483
# 170    0.395701
# 171    0.242758
# 172    1.022769
# Name: Total, Length: 173, dtype: float64
# 0       9.080376
# 1      28.093915
# ...

# %%
for total in range(len(college)):
    print(college.iloc[:,3])
# Out:
# 0       2339.0
# 1        756.0
# 2        856.0
# 3       1258.0
# 4      32260.0
#         ...
# 168     8409.0
# 169     2854.0
# 170     2838.0
# 171     4626.0
# 172     1098.0
# Name: Total, Length: 173, dtype: float64
# 0       2339.0
# 1        756.0
# 2        856.0
# 3       1258.0
# 4      32260.0
#         ...
# 168     8409.0
# 169     2854.0
# 170     2838.0
# 171     4626.0
# 172     1098.0
# Name: Total, Length: 173, dtype: float64
# 0       2339.0
# 1        756.0
# 2        856.0
# 3       1258.0
# 4      32260.0
#         ...
# 168     8409.0
# 169     2854.0
# 170     2838.0
# 171     4626.0
# 172     1098.0
# Name: Total, Length: 173, dtype: float64
# 0       2339.0
# 1        756.0
# 2        856.0
# 3       1258.0
# 4      32260.0
#         ...
# 168     8409.0
# 169     2854.0
# 170     2838.0
# 171     4626.0
# 172     1098.0
# Name: Total, Length: 173, dtype: float64
# 0       2339.0
# 1        756.0
# 2        856.0
# 3       1258.0
# 4      32260.0
# ...

# %%
college.iloc[:,3]
# Out:
# 0       2339.0
# 1        756.0
# 2        856.0
# 3       1258.0
# 4      32260.0
#         ...
# 168     8409.0
# 169     2854.0
# 170     2838.0
# 171     4626.0
# 172     1098.0
# Name: Total, Length: 173, dtype: float64

# %% [markdown]
# For problem above : https://www.geeksforgeeks.org/different-ways-to-iterate-over-rows-in-pandas-dataframe/
