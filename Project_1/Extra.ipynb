# %%
import pandas as pd

# %%
from pandas_profiling import ProfileReport

# %%
college = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv')
college
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %% [markdown]
# Question #1 --- How many Majors are in each Major_category?

# %%
count = college.groupby('Major_category').Major_category.count()
#count.sort_values()
type(count)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Question #2 ---- Find all the majors in health category where the women outnumber the men (not done yet... need to find the ones where women dominate)

# %%
Business = college.loc[college.Major_category == 'Business']
Business.loc[Business.ShareWomen >= 0.5]
# Out:
#      Rank  Major_code                                     Major     Total  \
# 40     41        6201                                ACCOUNTING  198633.0
# 59     60        6210                    INTERNATIONAL BUSINESS   25894.0
# 77     78        6206          MARKETING AND MARKETING RESEARCH  205211.0
# 86     87        6209  HUMAN RESOURCES AND PERSONNEL MANAGEMENT   24497.0
# 127   128        6211                    HOSPITALITY MANAGEMENT   43647.0
#
#          Men     Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 40   94519.0  104114.0       Business    0.524153         2042    165527  ...
# 59   10624.0   15270.0       Business    0.589712          260     19660  ...
# 77   78857.0  126354.0       Business    0.615727         2684    178862  ...
# 86    6184.0   18313.0       Business    0.747561          264     20760  ...
# 127  15204.0   28443.0       Business    0.651660          546     36728  ...
#
# ...

# %% [markdown]
# Question #3 ---- Find all the majors where women dominate men

# %%
women = college.loc[college.ShareWomen >= 0.5]
women
# Out:
#      Rank  Major_code                                              Major  \
# 7       8        5001                         ASTRONOMY AND ASTROPHYSICS
# 29     30        5402                                      PUBLIC POLICY
# 34     35        6107                                            NURSING
# 39     40        5102  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 40     41        6201                                         ACCOUNTING
# ..    ...         ...                                                ...
# 168   169        3609                                            ZOOLOGY
# 169   170        5201                             EDUCATIONAL PSYCHOLOGY
# 170   171        5202                                CLINICAL PSYCHOLOGY
# 171   172        5203                              COUNSELING PSYCHOLOGY
# 172   173        3501                                    LIBRARY SCIENCE
#
#         Total      Men     Women            Major_category  ShareWomen  \
# ...

# %% [markdown]
# Question #4 --- How many people got a fulltime college job thats not minimum wage (need to smooth out and make cleaner)

# %%
total = college.iloc[:,3].sum()
#print(total)
 
low_wage = college.iloc[:,-1].sum()
#print(low_wage)

collegejob = college.iloc[:,-3].sum()
#print(collegejob)

fulltime = college.iloc[:,-9].sum()
#print(fulltime)

math = collegejob + fulltime

smart_people = total - math

smart_people
# Out:
# 565092.0

# %% [markdown]
# Question #5 --- Create a new column called ShareMen next to the ShareWomen and plug in the share of men for each major

# %%
college['ShareMen'] = college['Men'] / college['Total']
college = college[['Rank','Major_code','Major','Total','Men','Women','Major_category','ShareWomen', 'ShareMen','Sample_size','Employed','Part_time','Full_time_year_round','Unemployed','Unemployment_rate','Median','P25th','P75th','College_jobs','Non_college_jobs','']]
college
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  ShareMen  \
# ...

# %% [markdown]
# Question #6 ---- Group together the Jobs in Engineering and put them in order from the one with the most people with a college job to least amount with a college job

# %%
#Engineering = college.loc([college.Major_category == 'Engineering']
#jobs = college['College_jobs'].sort_values()
#jobs.to_frame()
jobs = college.sort_values(by=['College_jobs'], ascending=False)
engineering = jobs.loc[college.Major_category == 'Engineering']
engineering
# Out:
#     Rank  Major_code                                        Major    Total  \
# 8      9        2414                       MECHANICAL ENGINEERING  91227.0
# 9     10        2408                       ELECTRICAL ENGINEERING  81527.0
# 25    26        2406                            CIVIL ENGINEERING  53153.0
# 17    18        2400                          GENERAL ENGINEERING  61152.0
# 10    11        2407                         COMPUTER ENGINEERING  41542.0
# 4      5        2405                         CHEMICAL ENGINEERING  32260.0
# 58    59        1401                                 ARCHITECTURE  46420.0
# 16    17        2412     INDUSTRIAL AND MANUFACTURING ENGINEERING  18968.0
# 11    12        2401                        AEROSPACE ENGINEERING  15058.0
# 12    13        2404                       BIOMEDICAL ENGINEERING  14955.0
# 22    23        2502            ELECTRICAL ENGINEERING TECHNOLOGY  11565.0
# ...

# %%
jobs = college['College_jobs']
jobs.sort_values()
# Out:
# 73          0
# 39        162
# 75        221
# 172       288
# 120       346
#         ...
# 113     82007
# 123     88232
# 138    108085
# 145    125148
# 34     151643
# Name: College_jobs, Length: 173, dtype: int64

# %% [markdown]
# find correlation betweeen employed and not employed for all the majors in Biology and life science

# %%
Bio = college.loc[college.Major_category == 'Biology & Life Science']
Correlation = Bio['Employed'].corr(Bio['Unemployed'])
Correlation
# Out:
# 0.9991520033202033
