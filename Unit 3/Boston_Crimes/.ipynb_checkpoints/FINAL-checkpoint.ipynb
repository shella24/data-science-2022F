# %%
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
import seaborn as sns
#profile = crimes.profile_report(title='Boston Crimes Profiling')
#profile.to_file(output_file='boston-crimes-profiling.html')
crimes = pd.read_csv('crime.csv')

# %%
crimes
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA SHOOTING  \
# 0                        LARCENY ALL OTHERS      D14           808.0      NaN
# 1                                 VANDALISM      C11           347.0      NaN
# 2                       TOWED MOTOR VEHICLE       D4           151.0      NaN
# 3                      INVESTIGATE PROPERTY       D4           272.0      NaN
# 4                      INVESTIGATE PROPERTY       B3           421.0      NaN
# ...                                     ...      ...             ...      ...
# 319068                       WARRANT ARREST       D4           285.0      NaN
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18           520.0      NaN
# 319070                       WARRANT ARREST      E18           520.0      NaN
# 319071                       WARRANT ARREST      E13           569.0      NaN
# 319072                       WARRANT ARREST       D4           903.0      NaN
#
#            OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0       2018-09-02 13:00:00  2018      9      Sunday    13    Part One
# 1        2018-08-21 0:00:00  2018      8     Tuesday     0    Part Two
# 2       2018-09-03 19:27:00  2018      9      Monday    19  Part Three
# 3       2018-09-03 21:16:00  2018      9      Monday    21  Part Three
# 4       2018-09-03 21:05:00  2018      9      Monday    21  Part Three
# ...                     ...   ...    ...         ...   ...         ...
# 319068  2016-06-05 17:25:00  2016      6      Sunday    17  Part Three
# 319069  2015-07-09 13:38:00  2015      7    Thursday    13    Part One
# 319070  2015-07-09 13:38:00  2015      7    Thursday    13  Part Three
# 319071  2016-05-31 19:35:00  2016      5     Tuesday    19  Part Three
# 319072   2015-06-22 0:12:00  2015      6      Monday     0  Part Three
#
#                    STREET        Lat       Long                     Location
# 0              LINCOLN ST  42.357791 -71.139371  (42.35779134, -71.13937053)
# 1                HECLA ST  42.306821 -71.060300  (42.30682138, -71.06030035)
# 2             CAZENOVE ST  42.346589 -71.072429  (42.34658879, -71.07242943)
# 3              NEWCOMB ST  42.334182 -71.078664  (42.33418175, -71.07866441)
# 4                DELHI ST  42.275365 -71.090361  (42.27536542, -71.09036101)
# ...                   ...        ...        ...                          ...
# 319068        COVENTRY ST  42.336951 -71.085748  (42.33695098, -71.08574813)
# 319069           RIVER ST  42.255926 -71.123172  (42.25592648, -71.12317207)
# 319070           RIVER ST  42.255926 -71.123172  (42.25592648, -71.12317207)
# 319071  NEW WASHINGTON ST  42.302333 -71.111565  (42.30233307, -71.11156487)
# 319072      WASHINGTON ST  42.333839 -71.080290  (42.33383935, -71.08029038)
#
# [319073 rows x 17 columns]

# %%
crimes.OCCURRED_ON_DATE = pd.to_datetime(crimes.OCCURRED_ON_DATE)

# %%
countOCG = crimes.groupby('OFFENSE_CODE_GROUP').OFFENSE_CODE_GROUP.count()
countOCG.sort_values()
# Out:
# OFFENSE_CODE_GROUP
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE        2
# Burglary - No Property Taken                     2
# Biological Threat                                2
# INVESTIGATE PERSON                               4
# HUMAN TRAFFICKING                                7
#                                              ...
# Other                                        18075
# Investigate Person                           18750
# Medical Assistance                           23540
# Larceny                                      25935
# Motor Vehicle Accident Response              37132
# Name: OFFENSE_CODE_GROUP, Length: 67, dtype: int64

# %%
crimes.SHOOTING = crimes.SHOOTING.replace({'Y': 1, 'NaN': 0})
crimes
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA  \
# 0                        LARCENY ALL OTHERS      D14           808.0
# 1                                 VANDALISM      C11           347.0
# 2                       TOWED MOTOR VEHICLE       D4           151.0
# 3                      INVESTIGATE PROPERTY       D4           272.0
# 4                      INVESTIGATE PROPERTY       B3           421.0
# ...                                     ...      ...             ...
# 319068                       WARRANT ARREST       D4           285.0
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18           520.0
# 319070                       WARRANT ARREST      E18           520.0
# 319071                       WARRANT ARREST      E13           569.0
# 319072                       WARRANT ARREST       D4           903.0
#
#         SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0            NaN 2018-09-02 13:00:00  2018      9      Sunday    13
# 1            NaN 2018-08-21 00:00:00  2018      8     Tuesday     0
# 2            NaN 2018-09-03 19:27:00  2018      9      Monday    19
# 3            NaN 2018-09-03 21:16:00  2018      9      Monday    21
# 4            NaN 2018-09-03 21:05:00  2018      9      Monday    21
# ...          ...                 ...   ...    ...         ...   ...
# 319068       NaN 2016-06-05 17:25:00  2016      6      Sunday    17
# 319069       NaN 2015-07-09 13:38:00  2015      7    Thursday    13
# 319070       NaN 2015-07-09 13:38:00  2015      7    Thursday    13
# 319071       NaN 2016-05-31 19:35:00  2016      5     Tuesday    19
# 319072       NaN 2015-06-22 00:12:00  2015      6      Monday     0
#
#           UCR_PART             STREET        Lat       Long  \
# 0         Part One         LINCOLN ST  42.357791 -71.139371
# 1         Part Two           HECLA ST  42.306821 -71.060300
# 2       Part Three        CAZENOVE ST  42.346589 -71.072429
# 3       Part Three         NEWCOMB ST  42.334182 -71.078664
# 4       Part Three           DELHI ST  42.275365 -71.090361
# ...            ...                ...        ...        ...
# 319068  Part Three        COVENTRY ST  42.336951 -71.085748
# 319069    Part One           RIVER ST  42.255926 -71.123172
# 319070  Part Three           RIVER ST  42.255926 -71.123172
# 319071  Part Three  NEW WASHINGTON ST  42.302333 -71.111565
# 319072  Part Three      WASHINGTON ST  42.333839 -71.080290
#
#                            Location
# 0       (42.35779134, -71.13937053)
# 1       (42.30682138, -71.06030035)
# 2       (42.34658879, -71.07242943)
# 3       (42.33418175, -71.07866441)
# 4       (42.27536542, -71.09036101)
# ...                             ...
# 319068  (42.33695098, -71.08574813)
# 319069  (42.25592648, -71.12317207)
# 319070  (42.25592648, -71.12317207)
# 319071  (42.30233307, -71.11156487)
# 319072  (42.33383935, -71.08029038)
#
# [319073 rows x 17 columns]

# %%
murder = crimes.loc[crimes.OFFENSE_CODE == 111]
shootingy = murder.loc[murder.SHOOTING == 1]
shootingn = murder.loc[murder.SHOOTING == 0]
counting = crimes.groupby('SHOOTING').SHOOTING.count()
shootingn
plot = counting.plot.pie(y='counting', figsize=(5, 5))

# %%
crimes.OCCURRED_ON_DATE = pd.to_datetime(crimes.OCCURRED_ON_DATE)
crimes['DATE'] = crimes.OCCURRED_ON_DATE
crimes
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA  \
# 0                        LARCENY ALL OTHERS      D14           808.0
# 1                                 VANDALISM      C11           347.0
# 2                       TOWED MOTOR VEHICLE       D4           151.0
# 3                      INVESTIGATE PROPERTY       D4           272.0
# 4                      INVESTIGATE PROPERTY       B3           421.0
# ...                                     ...      ...             ...
# 319068                       WARRANT ARREST       D4           285.0
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18           520.0
# 319070                       WARRANT ARREST      E18           520.0
# 319071                       WARRANT ARREST      E13           569.0
# 319072                       WARRANT ARREST       D4           903.0
#
#         SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0            NaN 2018-09-02 13:00:00  2018      9      Sunday    13
# 1            NaN 2018-08-21 00:00:00  2018      8     Tuesday     0
# 2            NaN 2018-09-03 19:27:00  2018      9      Monday    19
# 3            NaN 2018-09-03 21:16:00  2018      9      Monday    21
# 4            NaN 2018-09-03 21:05:00  2018      9      Monday    21
# ...          ...                 ...   ...    ...         ...   ...
# 319068       NaN 2016-06-05 17:25:00  2016      6      Sunday    17
# 319069       NaN 2015-07-09 13:38:00  2015      7    Thursday    13
# 319070       NaN 2015-07-09 13:38:00  2015      7    Thursday    13
# 319071       NaN 2016-05-31 19:35:00  2016      5     Tuesday    19
# 319072       NaN 2015-06-22 00:12:00  2015      6      Monday     0
#
#           UCR_PART             STREET        Lat       Long  \
# 0         Part One         LINCOLN ST  42.357791 -71.139371
# 1         Part Two           HECLA ST  42.306821 -71.060300
# 2       Part Three        CAZENOVE ST  42.346589 -71.072429
# 3       Part Three         NEWCOMB ST  42.334182 -71.078664
# 4       Part Three           DELHI ST  42.275365 -71.090361
# ...            ...                ...        ...        ...
# 319068  Part Three        COVENTRY ST  42.336951 -71.085748
# 319069    Part One           RIVER ST  42.255926 -71.123172
# 319070  Part Three           RIVER ST  42.255926 -71.123172
# 319071  Part Three  NEW WASHINGTON ST  42.302333 -71.111565
# 319072  Part Three      WASHINGTON ST  42.333839 -71.080290
#
#                            Location                DATE
# 0       (42.35779134, -71.13937053) 2018-09-02 13:00:00
# 1       (42.30682138, -71.06030035) 2018-08-21 00:00:00
# 2       (42.34658879, -71.07242943) 2018-09-03 19:27:00
# 3       (42.33418175, -71.07866441) 2018-09-03 21:16:00
# 4       (42.27536542, -71.09036101) 2018-09-03 21:05:00
# ...                             ...                 ...
# 319068  (42.33695098, -71.08574813) 2016-06-05 17:25:00
# 319069  (42.25592648, -71.12317207) 2015-07-09 13:38:00
# 319070  (42.25592648, -71.12317207) 2015-07-09 13:38:00
# 319071  (42.30233307, -71.11156487) 2016-05-31 19:35:00
# 319072  (42.33383935, -71.08029038) 2015-06-22 00:12:00
#
# [319073 rows x 18 columns]

# %%
sns.lineplot(data=crimes, x="DATE", y="MONTH")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 sns.lineplot(data=crimes, x="DATE", y="MONTH")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:499, in _LinePlotter.plot(self, ax, kws)
#     497         err = "estimator must be None when specifying units"
#     498         raise ValueError(err)
# --> 499     x, y, y_ci = self.aggregate(y, x, u)
#     500 else:
#     501     y_ci = None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:414, in _LinePlotter.aggregate(self, vals, grouper, units)
#     410     cis = pd.DataFrame(np.c_[est - sd, est + sd],
#     411                        index=est.index,
#     412                        columns=["low", "high"]).stack()
#     413 else:
# --> 414     cis = grouped.apply(bootstrapped_cis)
#     416 # Unpack the CIs into "wide" format for plotting
#     417 if cis.notnull().any():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/generic.py:244, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     238 @Appender(
#     239     _apply_docs["template"].format(
#     240         input="series", examples=_apply_docs["series_examples"]
#     241     )
#     242 )
#     243 def apply(self, func, *args, **kwargs):
# --> 244     return super().apply(func, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1414, in GroupBy.apply(self, func, *args, **kwargs)
#    1412 with option_context("mode.chained_assignment", None):
#    1413     try:
# -> 1414         result = self._python_apply_general(f, self._selected_obj)
#    1415     except TypeError:
#    1416         # gh-20949
#    1417         # try again, with .apply acting as a filtering
#    (...)
#    1421         # fails on *some* columns, e.g. a numeric operation
#    1422         # on a string grouper column
#    1424         with self._group_selection_context():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:1455, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1429 @final
#    1430 def _python_apply_general(
#    1431     self,
#    (...)
#    1434     not_indexed_same: bool | None = None,
#    1435 ) -> DataFrame | Series:
#    1436     """
#    1437     Apply function f in python space
#    1438
#    (...)
#    1453         data after applying f
#    1454     """
# -> 1455     values, mutated = self.grouper.apply(f, data, self.axis)
#    1457     if not_indexed_same is None:
#    1458         not_indexed_same = mutated or self.mutated
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py:761, in BaseGrouper.apply(self, f, data, axis)
#     759 # group might be modified
#     760 group_axes = group.axes
# --> 761 res = f(group)
#     762 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     763     mutated = True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py:395, in _LinePlotter.aggregate.<locals>.bootstrapped_cis(vals)
#     392 if len(vals) <= 1:
#     393     return null_ci
# --> 395 boots = bootstrap(vals, func=func, n_boot=n_boot, seed=seed)
#     396 cis = ci_func(boots, ci)
#     397 return pd.Series(cis, ["low", "high"])
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/algorithms.py:85, in bootstrap(*args, **kwargs)
#      83     resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
#      84     sample = [a.take(resampler, axis=0) for a in args]
# ---> 85     boot_dist.append(f(*sample, **func_kwargs))
#      86 return np.array(boot_dist)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/algorithms.py:66, in bootstrap.<locals>.f(x)
#      65 def f(x):
# ---> 66     return getattr(x, func)()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189, in _mean(a, axis, dtype, out, keepdims, where)
#     187         ret = arr.dtype.type(ret / rcount)
#     188     else:
# --> 189         ret = ret.dtype.type(ret / rcount)
#     190 else:
#     191     ret = ret / rcount
#
# KeyboardInterrupt:

# %%
vandalism = crimes.loc[crimes.OFFENSE_DESCRIPTION == 'VANDALISM']
sns.swarmplot(data=crimes, x="OFFENSE_DESCRIPTION", y="DAY_OF_WEEK", hue="DAY_OF_WEEK")
